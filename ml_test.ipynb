# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import sqlalchemy
from sqlalchemy import create_engine, inspect

import pandas as pd
import tensorflow as tf

# %% [markdown]
# ## Import datasets

# %%
# Import the data
engine = create_engine("sqlite:///voice.sqlite")

# View all of the classes
inspector = inspect(engine)
table_names = inspector.get_table_names()
table_names
# Out:
# ['demographic', 'diagnosis', 'habits']

# %%
# Initialise a dictionary to hold dataframes
dataframes = dict()

# Loop through each table
for table in table_names:
    
    # Dataframe name
    df_name = f'{table}_df'
    
    # Create dataframe
    dataframes[df_name] = pd.read_sql(
        f'SELECT * FROM {table}',
        engine
    )

# %%
dataframes['demographic_df']['id'].value_counts()
# Out:
# id
# voice005    2
# voice055    2
# voice100    1
# voice137    1
# voice140    1
#            ..
# voice080    1
# voice081    1
# voice153    1
# voice152    1
# voice024    1
# Name: count, Length: 206, dtype: int64

# %%
dataframes['diagnosis_df']
# Out:
#            id               diagnosis                subtype  vhi_score  \
# 0    voice100                 healthy             no subtype          0
# 1    voice101                 healthy             no subtype         80
# 2    voice192  hyperkinetic dysphonia             no subtype          0
# 3    voice193  hyperkinetic dysphonia             no subtype          0
# 4    voice008       reflux laryngitis             no subtype         19
# ..        ...                     ...                    ...        ...
# 203  voice180                 healthy             no subtype          0
# 204  voice164  hyperkinetic dysphonia             no subtype         34
# 205  voice165   hypokinetic dysphonia  glottic insufficiency         97
# 206  voice025                 healthy             no subtype         16
# 207  voice024                 healthy             no subtype          6
#
#      rsi_score
# 0            5
# 1           10
# 2           10
# 3           36
# 4           15
# ..         ...
# 203          3
# 204          1
# 205         16
# 206          1
# 207         12
#
# [208 rows x 5 columns]

# %%
dataframes['habits_df']
# Out:
#            id alcohol_consumption  alcohol_pd smoker  cigarettes_pd  \
# 0    voice100              casual        0.36     no              0
# 1    voice101          nondrinker        0.00     no              0
# 2    voice192          nondrinker        0.00     no              0
# 3    voice193              casual        0.36    yes             15
# 4    voice008              casual        0.36     no              0
# ..        ...                 ...         ...    ...            ...
# 203  voice180              casual        0.36     no              0
# 204  voice164              casual        0.36     no              0
# 205  voice165              casual        0.36     no              0
# 206  voice025            habitual        1.00     no              0
# 207  voice024              casual        0.36     no              0
#
#     carbonated_beverages  carbonated_pd      chocolate  chocolate_grams_pd  \
# 0          almost always           3.00      sometimes                  30
# 1          almost always           3.00      sometimes                  30
# 2                  never           0.00         always                  14
# 3              sometimes           0.61      sometimes                  30
# 4           almost never           0.09  almost always                  20
# ..                   ...            ...            ...                 ...
# 203                never           0.00      sometimes                  30
# 204            sometimes           0.61      sometimes                  30
# 205            sometimes           0.61      sometimes                  30
# 206         almost never           0.09      sometimes                  10
# 207                never           0.00   almost never                  28
#
#         coffee  coffee_pd  citrus_fruits  citrus_fruits_pd    soft_cheese  \
# 0       always          3          never              0.00  almost always
# 1       always          4          never              0.00      sometimes
# 2       always          3  almost always              1.00      sometimes
# 3       always          2      sometimes              1.00      sometimes
# 4       always          2  almost always              1.00      sometimes
# ..         ...        ...            ...               ...            ...
# 203      never          0          never              0.00      sometimes
# 204  sometimes          2      sometimes              1.00      sometimes
# 205  sometimes          2          never              0.00   almost never
# 206     always          1  almost always              1.00      sometimes
# 207     always          1      sometimes              0.14      sometimes
#
#      soft_cheese_pd       tomatoes  water_litres_pd
# 0               100          never              1.5
# 1               115      sometimes              1.5
# 2               115      sometimes              2.5
# 3               115      sometimes              1.0
# 4               100  almost always              1.0
# ..              ...            ...              ...
# 203             115      sometimes              1.5
# 204             115      sometimes              1.0
# 205             100      sometimes              1.5
# 206               5      sometimes              1.5
# 207               5      sometimes              1.5
#
# [208 rows x 17 columns]

# %%
print(dataframes['demographic_df']['id'].dtype)
print(dataframes['diagnosis_df']['id'].dtype)
# Out:
# object
# object

# %%
print(dataframes['demographic_df']['id'].value_counts())
print(dataframes['diagnosis_df']['id'].dtype)
# Out:
# id
# voice005    2
# voice055    2
# voice100    1
# voice137    1
# voice140    1
#            ..
# voice080    1
# voice081    1
# voice153    1
# voice152    1
# voice024    1
# Name: count, Length: 206, dtype: int64
# object

# %%
# Merge dataframes
merged_df = pd.merge(
    dataframes['demographic_df'],
    dataframes['diagnosis_df'],
    how = 'left',
    on = 'id'
)

# merged_df = pd.merge(
#     merged_df,
#     dataframes['habits_df'],
#     # how = 'inner',
#     on = 'id'
# )

# Display merged_df
merged_df
# Out:
#            id  age gender occupation_status               diagnosis  \
# 0    voice100   24      m           unknown                 healthy
# 1    voice101   60      m           unknown                 healthy
# 2    voice192   22      m              cook  hyperkinetic dysphonia
# 3    voice193   46      f         housewife  hyperkinetic dysphonia
# 4    voice008   51      f        researcher       reflux laryngitis
# ..        ...  ...    ...               ...                     ...
# 207  voice180   26      f           student                 healthy
# 208  voice164   65      f         pensioner  hyperkinetic dysphonia
# 209  voice165   55      m       hairstylist   hypokinetic dysphonia
# 210  voice025   45      m        researcher                 healthy
# 211  voice024   38      m        researcher                 healthy
#
#                    subtype  vhi_score  rsi_score
# 0               no subtype          0          5
# 1               no subtype         80         10
# 2               no subtype          0         10
# 3               no subtype          0         36
# 4               no subtype         19         15
# ..                     ...        ...        ...
# 207             no subtype          0          3
# 208             no subtype         34          1
# 209  glottic insufficiency         97         16
# 210             no subtype         16          1
# 211             no subtype          6         12
#
# [212 rows x 8 columns]

# %%
merged_df['id'].value_counts(dropna=False)
# Out:
# id
# voice005    4
# voice055    4
# voice100    1
# voice137    1
# voice140    1
#            ..
# voice080    1
# voice081    1
# voice153    1
# voice152    1
# voice024    1
# Name: count, Length: 206, dtype: int64

# %%
merged_df.loc[merged_df['id'] == 'voice005']
# Out:
#            id  age gender occupation_status              diagnosis  \
# 99   voice005   54      f        researcher  hypokinetic dysphonia
# 100  voice005   54      f        researcher  hypokinetic dysphonia
# 163  voice005   54      f        researcher  hypokinetic dysphonia
# 164  voice005   54      f        researcher  hypokinetic dysphonia
#
#         subtype  vhi_score  rsi_score
# 99   no subtype         39         23
# 100  no subtype         39         25
# 163  no subtype         39         23
# 164  no subtype         39         25
