# %% [markdown]
# # Build the Database

# %%
# Import dependencies
import sqlalchemy
from sqlalchemy import create_engine, inspect

import os
import pandas as pd

# %%
# Create the engine
engine = create_engine("sqlite:///voice.sqlite")

# %%
# Define the file path
file_path = "../resources/clean_data/"

# Get all files in the directory
files = os.listdir(file_path)

# %%
# Create a dictionary to hold each df
dataframes = dict()

# Loop through all files
for file in files:
    
    # Return CSV files only
    if file.endswith(".csv"):
        
        # Get the file name
        filename = file.split(".")[0]
        
        # Dataframe name
        df_name = f'{filename}_df'
        
        # Create dataframe and add to dictionary
        dataframes[df_name] = pd.read_csv(file_path + file)

# Display the first dataframe
dataframes['habits_df'].head()
# Out:
#          id alcohol_consumption  alcohol_pd smoker  cigarettes_pd  \
# 0  voice100              casual        0.36     no              0
# 1  voice101          nondrinker        0.00     no              0
# 2  voice192          nondrinker        0.00     no              0
# 3  voice193              casual        0.36    yes             15
# 4  voice008              casual        0.36     no              0
#
#   carbonated_beverages  carbonated_pd      chocolate  chocolate_grams_pd  \
# 0        almost always           3.00      sometimes                  30
# 1        almost always           3.00      sometimes                  30
# 2                never           0.00         always                  14
# 3            sometimes           0.61      sometimes                  30
# 4         almost never           0.09  almost always                  20
#
#    coffee  coffee_pd  citrus_fruits  citrus_fruits_pd    soft_cheese  \
# 0  always          3          never              0.00  almost always
# 1  always          4          never              0.00      sometimes
# 2  always          3  almost always              1.17      sometimes
# 3  always          2      sometimes              1.00      sometimes
# 4  always          2  almost always              1.00      sometimes
#
#    soft_cheese_pd       tomatoes  water_litres_pd
# 0             100          never              1.5
# 1             100      sometimes              1.5
# 2             100      sometimes              2.5
# 3             100      sometimes              1.0
# 4             100  almost always              1.0

# %%
# Write the dataframes to the database
for key, value in dataframes.items():
    
    # Define the table name
    table_name = key.split("_")[0]
    
    # Use to_sql()
    value.to_sql(
        table_name,
        con = engine,
        if_exists = "replace",
        index = False
    )

# %%
# View all of the classes
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['aval',
#  'bval',
#  'demographic',
#  'diagnosis',
#  'gval',
#  'habits',
#  'rval',
#  'spectrogram',
#  'stfeatures']

# %%
test_df = pd.read_sql('SELECT * FROM stfeatures', engine)
test_df
# Out:
#          id                                                zcr  \
# 0  voice094  [0.         0.         0.         0.11027569 0...
# 1  voice080  [0.         0.         0.         0.06015038 0...
# 2  voice057  [0.         0.         0.         0.03007519 0...
#
#                                               energy  \
# 0  [6.03695694e-07 6.03695694e-07 6.03695694e-07 ...
# 1  [6.72508333e-07 6.72508333e-07 6.72508333e-07 ...
# 2  [3.99905252e-07 3.99905252e-07 3.99905252e-07 ...
#
#                                       energy_entropy  \
# 0  [3.32192809 3.32192809 3.32192809 1.19564489 2...
# 1  [3.32192809 3.32192809 3.32192809 0.9905598  2...
# 2  [3.32192809 3.32192809 3.32192809 0.86631004 2...
#
#                                    spectral_centroid  \
# 0  [0.005      0.005      0.005      0.44183873 0...
# 1  [0.005      0.005      0.005      0.30244431 0...
# 2  [0.005      0.005      0.005      0.23777973 0...
#
#                                      spectral_spread  \
# 0  [3.25577952e-09 3.25577952e-09 3.25577952e-09 ...
# 1  [8.88178420e-19 8.88178420e-19 8.88178420e-19 ...
# 2  [2.55185052e-09 2.55185052e-09 2.55185052e-09 ...
#
#                                     spectral_entropy  \
# 0  [1.32658697e-10 1.32658697e-10 1.32658697e-10 ...
# 1  [1.19084657e-10 1.19084657e-10 1.19084657e-10 ...
# 2  [2.00261247e-10 2.00261247e-10 2.00261247e-10 ...
#
#                                        spectral_flux  \
# 0  [0.         0.         0.         0.98239665 0...
# 1  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ...
# 2  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ...
#
#                                     spectral_rolloff  \
# 0  [0.    0.    0.    0.83  0.82  0.8   0.8   0.7...
# 1  [0.    0.    0.    0.355 0.34  0.345 0.345 0.3...
# 2  [0.    0.    0.    0.19  0.195 0.19  0.18  0.1...
#
#                                               mfcc_1  ...  \
# 0  [-99.00180446 -99.00180446 -99.00180446 -30.12...  ...
# 1  [-99.00180475 -99.00180475 -99.00180475 -25.51...  ...
# 2  [-99.00180461 -99.00180461 -99.00180461 -26.40...  ...
#
#                                       delta chroma_4  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                       delta chroma_5  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.          0.          0.          0.018390...
#
#                                       delta chroma_6  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                       delta chroma_7  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                       delta chroma_8  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                       delta chroma_9  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.          0.          0.          0.029250...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                      delta chroma_10  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                      delta chroma_11  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                      delta chroma_12  \
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
#                                     delta chroma_std
# 0  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 1  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
# 2  [ 0.00000000e+00  0.00000000e+00  0.00000000e+...
#
# [3 rows x 69 columns]

# %%
test_df['energy'][0]
# Out:
# '[6.03695694e-07 6.03695694e-07 6.03695694e-07 7.77826087e-05\n 4.26915240e-04 1.35723569e-03 2.13498010e-03 2.81156223e-03\n 4.33193426e-03 6.56625330e-03 7.92548937e-03 1.01575500e-02\n 1.29233972e-02 1.53461461e-02 1.54351871e-02 1.49313530e-02\n 1.67554562e-02 1.84047608e-02 1.86774538e-02 1.90750231e-02\n 1.99158060e-02 2.01437413e-02 2.00815677e-02 2.11317375e-02\n 2.06881772e-02 1.98980863e-02 2.13243086e-02 2.23302903e-02\n 2.38940355e-02 2.48959651e-02 2.41213793e-02 2.39896302e-02\n 2.65762945e-02 2.92940846e-02 2.68020119e-02 2.22437892e-02\n 2.48940296e-02 2.69895654e-02 2.52576976e-02 2.53511594e-02\n 2.56547052e-02 2.48863010e-02 2.25776873e-02 2.27177521e-02\n 2.45477398e-02 2.50199139e-02 2.33035708e-02 2.17558155e-02\n 2.24711683e-02 2.26009565e-02 2.18117942e-02 2.07422877e-02\n 2.30034943e-02 2.27605991e-02 2.10687342e